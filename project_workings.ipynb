# %% [markdown]
# ### Arena Media: Battle of Neighborhood

# %%
# Importing and installing the required libraries
# Install missing modules
! pip install geopy
! pip install folium
! pip install requests

#Import the modules
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
from IPython.display import Image # libraries for displaying images
from IPython.core.display import HTML # libraries for displaying images
from pandas.io.json import json_normalize #tranforming json file into a pandas dataframe library
import folium # plotting library
# Out:
# Requirement already satisfied: geopy in ./korir_env/lib/python3.5/site-packages (1.20.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in ./korir_env/lib/python3.5/site-packages (from geopy) (1.49)
# Requirement already satisfied: folium in ./korir_env/lib/python3.5/site-packages (0.8.3)
# Requirement already satisfied: numpy in ./korir_env/lib/python3.5/site-packages (from folium) (1.16.3)
# Requirement already satisfied: jinja2 in ./korir_env/lib/python3.5/site-packages (from folium) (2.10.1)
# Requirement already satisfied: branca>=0.3.0 in ./korir_env/lib/python3.5/site-packages (from folium) (0.3.1)
# Requirement already satisfied: six in ./korir_env/lib/python3.5/site-packages (from folium) (1.12.0)
# Requirement already satisfied: requests in ./korir_env/lib/python3.5/site-packages (from folium) (2.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in ./korir_env/lib/python3.5/site-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in ./korir_env/lib/python3.5/site-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./korir_env/lib/python3.5/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./korir_env/lib/python3.5/site-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in ./korir_env/lib/python3.5/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: requests in ./korir_env/lib/python3.5/site-packages (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./korir_env/lib/python3.5/site-packages (from requests) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in ./korir_env/lib/python3.5/site-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in ./korir_env/lib/python3.5/site-packages (from requests) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./korir_env/lib/python3.5/site-packages (from requests) (3.0.4)

# %%
# Lets define foursquare credentials

ClIENT_ID = 'J1F24KJMK4YD0QK00HGFLEOBJRKH5XGLOJBPY4DLKSQGPKK0' # your Foursquare ID
ClIENT_SECRET = 'LAJR2Q0ZUAGDBFPRY4N3AQF50NBK0WSBYZX0RVFMHZWP5JU0' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: J1F24KJMK4YD0QK00HGFLEOBJRKH5XGLOJBPY4DLKSQGPKK0
# Foursquare_Secret:LAJR2Q0ZUAGDBFPRY4N3AQF50NBK0WSBYZX0RVFMHZWP5JU0

# %%
# Lets define the city and get its latitude & longitude 

city = 'Toronto'
geolocator = Nominatim(user_agent = "foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %%
# lets search for hotels

search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=J1F24KJMK4YD0QK00HGFLEOBJRKH5XGLOJBPY4DLKSQGPKK0&client_secret=LAJR2Q0ZUAGDBFPRY4N3AQF50NBK0WSBYZX0RVFMHZWP5JU0&ll=43.653963,-79.387207&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Lets send the GET Request and examine the results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d08bcb7018cbb002ca01a3b'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4ab2d511f964a5209b6c20e3',
#     'location': {'address': '123 Queen Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at York St.',
#      'distance': 416,
#      'formattedAddress': ['123 Queen Street West (at York St.)',
#       'Toronto ON M5H 2M9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651129283252786,
#        'lng': -79.38382900313331}],
#      'lat': 43.651129283252786,
#      'lng': -79.38382900313331,
#      'postalCode': 'M5H 2M9',
#      'state': 'ON'},
#     'name': 'Sheraton Centre Toronto Hotel',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '58b7d72dcc05d161570bd712',
#     'location': {'address': '123 Queen Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 410,
#      'formattedAddress': ['123 Queen Street West',
#       'Toronto ON M5H 2M9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65101646682632,
#        'lng': -79.38414798735793}],
#      'lat': 43.65101646682632,
#      'lng': -79.38414798735793,
#      'postalCode': 'M5H 2M9',
#      'state': 'ON'},
#     'name': 'Sheraton Centre Toronto Hotel',
#     'referralId': 'v-1560853687',
#     'venuePage': {'id': '402127087'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'primary': True,
#       'shortName': 'Jazz Club'}],
#     'hasPerk': False,
#     'id': '4b68aed1f964a520de862be3',
#     'location': {'address': '194 Queen St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Queen & St. Patrick',
#      'distance': 400,
#      'formattedAddress': ['194 Queen St W (Queen & St. Patrick)',
#       'Toronto ON M5V 1Z1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65050475544005,
#        'lng': -79.38857723389897}],
#      'lat': 43.65050475544005,
#      'lng': -79.38857723389897,
#      'postalCode': 'M5V 1Z1',
#      'state': 'ON'},
#     'name': 'The Rex Hotel Jazz & Blues Bar',
#     'referralId': 'v-1560853687',
#     'venuePage': {'id': '62225795'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '52ce14b0498e50457ce11780',
#     'location': {'address': '108 Chestnut Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas St W',
#      'distance': 124,
#      'formattedAddress': ['108 Chestnut Street (Dundas St W)',
#       'Toronto ON M5G 1R3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6546083,
#        'lng': -79.3859415}],
#      'lat': 43.6546083,
#      'lng': -79.3859415,
#      'postalCode': 'M5G 1R3',
#      'state': 'ON'},
#     'name': 'DoubleTree by Hilton Hotel Toronto Downtown',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4f343a31e4b0230a3b337a90',
#     'location': {'address': '123 Test Drive',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at somewhere St',
#      'distance': 500,
#      'formattedAddress': ['123 Test Drive (at somewhere St)',
#       'Toronto ON M2M 2M2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658434,
#        'lng': -79.387894}],
#      'lat': 43.658434,
#      'lng': -79.387894,
#      'postalCode': 'M2M 2M2',
#      'state': 'ON'},
#     'name': 'VFM Test Hotel',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '56aa371be4b08b9a8d5734cf',
#       'name': 'Ballroom',
#       'pluralName': 'Ballrooms',
#       'primary': True,
#       'shortName': 'Ballroom'}],
#     'hasPerk': False,
#     'id': '5545d07e498e2facac03f666',
#     'location': {'address': '123 Queen Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Bay Street',
#      'distance': 376,
#      'formattedAddress': ['123 Queen Street West (at Bay Street)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65119976208405,
#        'lng': -79.38452034718189}],
#      'lat': 43.65119976208405,
#      'lng': -79.38452034718189,
#      'neighborhood': 'Financial District',
#      'state': 'ON'},
#     'name': 'Sheraton Centre Toronto Hotel - Grand Ballroom',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4f53fb2ee4b036244bea152f',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 129,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654947,
#        'lng': -79.386359}],
#      'lat': 43.654947,
#      'lng': -79.386359,
#      'state': 'ON'},
#     'name': 'Stathcona Hotel',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'primary': True,
#       'shortName': 'Pool'}],
#     'hasPerk': False,
#     'id': '52a7186411d216bd254733b1',
#     'location': {'address': 'Richmondstreet E, 145',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 396,
#      'formattedAddress': ['Richmondstreet E, 145', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6506246618514,
#        'lng': -79.3854884436715}],
#      'lat': 43.6506246618514,
#      'lng': -79.3854884436715,
#      'state': 'ON'},
#     'name': 'hilton hotel, richmondstreet E, 145,  toronto',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '53e3f70c498e8221abc0db4c',
#     'location': {'address': '650 Bay Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Elm Street',
#      'distance': 411,
#      'formattedAddress': ['650 Bay Street (Elm Street)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65711975097656,
#        'lng': -79.38455963134766}],
#      'lat': 43.65711975097656,
#      'lng': -79.38455963134766,
#      'state': 'ON'},
#     'name': 'Be SixFifty Hotel',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '55de0cf9498e74d841ab26c1',
#     'location': {'address': '650 Bay Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Elm Street',
#      'distance': 410,
#      'formattedAddress': ['650 Bay Street (Elm Street)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65704642307161,
#        'lng': -79.38441078793146}],
#      'lat': 43.65704642307161,
#      'lng': -79.38441078793146,
#      'state': 'ON'},
#     'name': '650 Hotel',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4a9d0a53f964a520d23720e3',
#     'location': {'address': '145 Richmond St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at University Ave',
#      'distance': 447,
#      'formattedAddress': ['145 Richmond St W (at University Ave)',
#       'Toronto ON M5H 2L2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6501425,
#        'lng': -79.3854884}],
#      'lat': 43.6501425,
#      'lng': -79.3854884,
#      'postalCode': 'M5H 2L2',
#      'state': 'ON'},
#     'name': 'Hilton Toronto',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4b0563c0f964a5200e5822e3',
#     'location': {'address': '525 Bay Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 394,
#      'formattedAddress': ['525 Bay Street', 'Toronto ON M5G 2L2', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654728444284025,
#        'lng': -79.3824216350913}],
#      'lat': 43.654728444284025,
#      'lng': -79.3824216350913,
#      'postalCode': 'M5G 2L2',
#      'state': 'ON'},
#     'name': 'Marriott Downtown at CF Toronto Eaton Centre',
#     'referralId': 'v-1560853687',
#     'venuePage': {'id': '129932611'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'primary': True,
#       'shortName': 'Gym'}],
#     'hasPerk': False,
#     'id': '4b5243a7f964a5209d7327e3',
#     'location': {'address': 'Sheraton Centre',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': '123 Queen St W',
#      'distance': 420,
#      'formattedAddress': ['Sheraton Centre (123 Queen St W)',
#       'Toronto ON M5H 2M9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65098505166592,
#        'lng': -79.38400232084814}],
#      'lat': 43.65098505166592,
#      'lng': -79.38400232084814,
#      'postalCode': 'M5H 2M9',
#      'state': 'ON'},
#     'name': 'Fitness Centre',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4e1632f31f6eb653a5e4aa66',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 85,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654235,
#        'lng': -79.386208}],
#      'lat': 43.654235,
#      'lng': -79.386208,
#      'state': 'ON'},
#     'name': 'Op mijn hotelkamer In Toronto',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/residencehall_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a3941735',
#       'name': 'College Residence Hall',
#       'pluralName': 'College Residence Halls',
#       'primary': True,
#       'shortName': 'Residence Hall'}],
#     'hasPerk': False,
#     'id': '4be18ce28dd062b548533e3c',
#     'location': {'address': '89 Chestnut St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Armoury St.',
#      'distance': 155,
#      'formattedAddress': ['89 Chestnut St. (at Armoury St.)',
#       'Toronto ON M5G 1R1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654159528349275,
#        'lng': -79.38529050784362}],
#      'lat': 43.654159528349275,
#      'lng': -79.38529050784362,
#      'postalCode': 'M5G 1R1',
#      'state': 'ON'},
#     'name': '89 Chestnut Residence',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4e31b74252b131dcebb08743',
#     'location': {'address': '188 University Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Adelaide St. W',
#      'distance': 540,
#      'formattedAddress': ['188 University Ave. (at Adelaide St. W)',
#       'Toronto ON M5H 0A3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64912919417502,
#        'lng': -79.3865566853963}],
#      'lat': 43.64912919417502,
#      'lng': -79.3865566853963,
#      'postalCode': 'M5H 0A3',
#      'state': 'ON'},
#     'name': 'Shangri-La Toronto',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'primary': True,
#       'shortName': 'Gym'}],
#     'hasPerk': False,
#     'id': '4ff8e46fe4b03705cefc7075',
#     'location': {'address': '525 Bay St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'in Marriott Downtown',
#      'distance': 447,
#      'formattedAddress': ['525 Bay St. (in Marriott Downtown)',
#       'Toronto ON M5G 2L2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654690455955546,
#        'lng': -79.3817385874303}],
#      'lat': 43.654690455955546,
#      'lng': -79.3817385874303,
#      'postalCode': 'M5G 2L2',
#      'state': 'ON'},
#     'name': 'Fitness Centre',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'primary': True,
#       'shortName': 'Lounge'}],
#     'hasPerk': False,
#     'id': '53856fa411d2061fc84a3d0a',
#     'location': {'address': '188 University Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 537,
#      'formattedAddress': ['188 University Ave.',
#       'Toronto ON M5H 0A3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64915499986854,
#        'lng': -79.38654574367817}],
#      'lat': 43.64915499986854,
#      'lng': -79.38654574367817,
#      'postalCode': 'M5H 0A3',
#      'state': 'ON'},
#     'name': 'Lobby Lounge at the Shangri-La Toronto',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'primary': True,
#       'shortName': 'Event Space'}],
#     'hasPerk': False,
#     'id': '4b958a8ef964a5205ca834e3',
#     'location': {'address': '123 Queen St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'in Sheraton Centre',
#      'distance': 412,
#      'formattedAddress': ['123 Queen St. W (in Sheraton Centre)',
#       'Toronto ON M5H 2M9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65121729803052,
#        'lng': -79.38377127936532}],
#      'lat': 43.65121729803052,
#      'lng': -79.38377127936532,
#      'postalCode': 'M5H 2M9',
#      'state': 'ON'},
#     'name': 'Grand Ballroom',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'primary': True,
#       'shortName': 'Pool'}],
#     'hasPerk': False,
#     'id': '515e0d16e4b0e99f5f4764a8',
#     'location': {'address': 'Intercontinental',
#      'cc': 'CA',
#      'country': 'Canada',
#      'distance': 418,
#      'formattedAddress': ['Intercontinental', 'Ontario', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65097492328021,
#        'lng': -79.38405339932878}],
#      'lat': 43.65097492328021,
#      'lng': -79.38405339932878,
#      'state': 'Ontario'},
#     'name': 'Pool',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d106951735',
#       'name': "Men's Store",
#       'pluralName': "Men's Stores",
#       'primary': True,
#       'shortName': "Men's Store"}],
#     'hasPerk': False,
#     'id': '4b0d95f7f964a520a14b23e3',
#     'location': {'address': 'Sheraton Centre',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': '123 Queen St W',
#      'distance': 452,
#      'formattedAddress': ['Sheraton Centre (123 Queen St W)',
#       'Toronto ON M5H 2M9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65104394334362,
#        'lng': -79.38330173492432}],
#      'lat': 43.65104394334362,
#      'lng': -79.38330173492432,
#      'postalCode': 'M5H 2M9',
#      'state': 'ON'},
#     'name': 'Kumar For Men',
#     'referralId': 'v-1560853687'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4b99106ef964a520f95e35e3',
#     'location': {'address': '123 Queen St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Sheraton Centre',
#      'distance': 435,
#      'formattedAddress': ['123 Queen St. W (at Sheraton Centre)',
#       'Toronto ON M5H 2M9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651010971392715,
#        'lng': -79.38365752111193}],
#      'lat': 43.651010971392715,
#      'lng': -79.38365752111193,
#      'postalCode': 'M5H 2M9',
#      'state': 'ON'},
#     'name': 'Bistro on Two',
#     'referralId': 'v-1560853687'}]}}

# %%
# Lets assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Hotel', 'id': '4bf58dd8d48988d1fa93...    False
# 1  [{'name': 'Hotel', 'id': '4bf58dd8d48988d1fa93...    False
# 2  [{'name': 'Jazz Club', 'id': '4bf58dd8d48988d1...    False
# 3  [{'name': 'Hotel', 'id': '4bf58dd8d48988d1fa93...    False
# 4  [{'name': 'Hotel', 'id': '4bf58dd8d48988d1fa93...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  58b7d72dcc05d161570bd712  123 Queen Street West          CA       Toronto
# 2  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 3  52ce14b0498e50457ce11780    108 Chestnut Street          CA       Toronto
# 4  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                416
# 1           Canada                  NaN                410
# 2           Canada  Queen & St. Patrick                400
# 3           Canada          Dundas St W                124
# 4           Canada      at somewhere St                500
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 2  [194 Queen St W (Queen & St. Patrick), Toronto...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65112928325278...     43.651129
# 1  [{'label': 'display', 'lat': 43.65101646682632...     43.651016
# 2  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 3  [{'label': 'display', 'lat': 43.6546083, 'lng'...     43.654608
# 4  [{'label': 'display', 'lat': 43.658434, 'lng':...     43.658434
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.383829                   NaN             M5H 2M9             ON
# 1    -79.384148                   NaN             M5H 2M9             ON
# 2    -79.388577                   NaN             M5V 1Z1             ON
# 3    -79.385942                   NaN             M5G 1R3             ON
# 4    -79.387894                   NaN             M2M 2M2             ON
#
#                                           name    referralId venuePage.id
# 0                Sheraton Centre Toronto Hotel  v-1560853687          NaN
# 1                Sheraton Centre Toronto Hotel  v-1560853687    402127087
# 2               The Rex Hotel Jazz & Blues Bar  v-1560853687     62225795
# 3  DoubleTree by Hilton Hotel Toronto Downtown  v-1560853687          NaN
# 4                               VFM Test Hotel  v-1560853687          NaN

# %%
# Lets keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                           name categories  \
# 0                Sheraton Centre Toronto Hotel      Hotel
# 1                Sheraton Centre Toronto Hotel      Hotel
# 2               The Rex Hotel Jazz & Blues Bar  Jazz Club
# 3  DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 4                               VFM Test Hotel      Hotel
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       416
# 1  123 Queen Street West  CA  Toronto  Canada                  NaN       410
# 2         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 3    108 Chestnut Street  CA  Toronto  Canada          Dundas St W       124
# 4         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 2  [194 Queen St W (Queen & St. Patrick), Toronto...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65112928325278...  43.651129 -79.383829
# 1  [{'label': 'display', 'lat': 43.65101646682632...  43.651016 -79.384148
# 2  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 3  [{'label': 'display', 'lat': 43.6546083, 'lng'...  43.654608 -79.385942
# 4  [{'label': 'display', 'lat': 43.658434, 'lng':...  43.658434 -79.387894
#
#   neighborhood postalCode state                        id
# 0          NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1          NaN    M5H 2M9    ON  58b7d72dcc05d161570bd712
# 2          NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 3          NaN    M5G 1R3    ON  52ce14b0498e50457ce11780
# 4          NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                    Sheraton Centre Toronto Hotel                   Hotel
# 2                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 3      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                   VFM Test Hotel                   Hotel
# 5   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 6                                  Stathcona Hotel                   Hotel
# 7    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 8                                Be SixFifty Hotel                   Hotel
# 9                                        650 Hotel                   Hotel
# 10                                  Hilton Toronto                   Hotel
# 11    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 12                                  Fitness Centre                     Gym
# 13                   Op mijn hotelkamer In Toronto                   Hotel
# 14                           89 Chestnut Residence  College Residence Hall
# 15                              Shangri-La Toronto                   Hotel
# 16                                  Fitness Centre                     Gym
# 17          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 18                                  Grand Ballroom             Event Space
# 19                                            Pool                    Pool
# 20                                   Kumar For Men             Men's Store
# 21                                   Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9       ON
# 1   123 Queen Street West  43.651016 -79.384148    M5H 2M9       ON
# 2          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 5   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 6                     NaN  43.654947 -79.386359        NaN       ON
# 7   Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 8          650 Bay Street  43.657120 -79.384560        NaN       ON
# 9          650 Bay Street  43.657046 -79.384411        NaN       ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2       ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 12        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 13                    NaN  43.654235 -79.386208        NaN       ON
# 14        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 15    188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 17    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 18        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON
# 19       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 20        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 21        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON

# %%
# Lets delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis = 0, how = 'any', thresh = None, subset = None, inplace = False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                  Sheraton Centre Toronto Hotel                   Hotel
# 2                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 3    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                 VFM Test Hotel                   Hotel
# 10                                Hilton Toronto                   Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 12                                Fitness Centre                     Gym
# 14                         89 Chestnut Residence  College Residence Hall
# 15                            Shangri-La Toronto                   Hotel
# 16                                Fitness Centre                     Gym
# 17        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 18                                Grand Ballroom             Event Space
# 20                                 Kumar For Men             Men's Store
# 21                                 Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 1   123 Queen Street West  43.651016 -79.384148    M5H 2M9    ON
# 2          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 12        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 14        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 15    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 17    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 18        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 20        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 21        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON

# %%
# Lets delete rows which its category is not Hotel or Event Space
array = ['Hotel', 'Event Space']
hotel_dataframe = clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 1                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 10                                Hilton Toronto        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 15                            Shangri-La Toronto        Hotel
# 18                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 1   123 Queen Street West  43.651016 -79.384148    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 15    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 18        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# Lets delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset = 'name', keep = "first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 10                                Hilton Toronto        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 15                            Shangri-La Toronto        Hotel
# 18                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 15    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 18        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# Lets choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 18                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651129 -79.383829    M5H 2M9    ON
# 18  43.651217 -79.383771    M5H 2M9    ON

# %%
# Lets search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=J1F24KJMK4YD0QK00HGFLEOBJRKH5XGLOJBPY4DLKSQGPKK0&client_secret=LAJR2Q0ZUAGDBFPRY4N3AQF50NBK0WSBYZX0RVFMHZWP5JU0&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Lets send the GET Request and examine the results
presults = requests.get(url).json()
presults
# Out:
# {'meta': {'code': 200, 'requestId': '5d08bd3d38f21600252ddf3a'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4b170e47f964a5208cc123e3',
#     'location': {'address': '691 University Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at College St',
#      'distance': 716,
#      'formattedAddress': ['691 University Ave (at College St)',
#       'Toronto ON M5G 2P1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.660006357009195,
#        'lng': -79.39027220226043}],
#      'lat': 43.660006357009195,
#      'lng': -79.39027220226043,
#      'postalCode': 'M5G 2P1',
#      'state': 'ON'},
#     'name': "Queen's Park Subway Station",
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4b54deadf964a520a3d027e3',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 423,
#      'formattedAddress': ['btwn College, University, Queen & Spadina',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652487552998565,
#        'lng': -79.39205307540142}],
#      'lat': 43.652487552998565,
#      'lng': -79.39205307540142,
#      'state': 'ON'},
#     'name': 'Grange Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4ad4c05ef964a520bdf620e3',
#     'location': {'address': '1053 Dundas St. W.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Gore Vale Ave.',
#      'distance': 2271,
#      'formattedAddress': ['1053 Dundas St. W. (at Gore Vale Ave.)',
#       'Toronto ON M5H 2N2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64707192840234,
#        'lng': -79.4137559260075}],
#      'lat': 43.64707192840234,
#      'lng': -79.4137559260075,
#      'postalCode': 'M5H 2N2',
#      'state': 'ON'},
#     'name': 'Trinity Bellwoods Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4bb3c91a2397b7134d9f38b3',
#     'location': {'address': 'Spadina Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Wellington St W',
#      'distance': 1223,
#      'formattedAddress': ['Spadina Ave (at Wellington St W)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64422227794523,
#        'lng': -79.3942301870698}],
#      'lat': 43.64422227794523,
#      'lng': -79.3942301870698,
#      'state': 'ON'},
#     'name': 'Clarence Square Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'primary': True,
#       'shortName': 'Residential'}],
#     'hasPerk': False,
#     'id': '4ad80fcef964a520a61021e3',
#     'location': {'address': '280 Simcoe St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas Street West',
#      'distance': 282,
#      'formattedAddress': ['280 Simcoe St (Dundas Street West)',
#       'Toronto ON M5T 2Y5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65544241747622,
#        'lng': -79.39005622787515}],
#      'lat': 43.65544241747622,
#      'lng': -79.39005622787515,
#      'postalCode': 'M5T 2Y5',
#      'state': 'ON'},
#     'name': 'One Park Lane',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'primary': True,
#       'shortName': 'Gym / Fitness'}],
#     'hasPerk': False,
#     'id': '59ddd7469ba3e51a75459568',
#     'location': {'address': '382 Yonge Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 695,
#      'formattedAddress': ['382 Yonge Street', 'Toronto ON M5G 1S8', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6592634,
#        'lng': -79.3826319}],
#      'lat': 43.6592634,
#      'lng': -79.3826319,
#      'postalCode': 'M5G 1S8',
#      'state': 'ON'},
#     'name': 'Crunch Fitness - College Park',
#     'referralId': 'v-1560853821',
#     'venuePage': {'id': '532736199'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4bfc5019da7120a132df49fd',
#     'location': {'address': '450 Adelaide Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Brant St & Adelaide St W',
#      'distance': 1183,
#      'formattedAddress': ['450 Adelaide Street West (Brant St & Adelaide St W)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64738759338116,
#        'lng': -79.39875217247466}],
#      'lat': 43.64738759338116,
#      'lng': -79.39875217247466,
#      'state': 'ON'},
#     'name': 'St. Andrews Playground / Dog Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4b797b48f964a520c6fb2ee3',
#     'location': {'address': 'btwn Bellevue & Augusta Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1208,
#      'formattedAddress': ['btwn Bellevue & Augusta Ave.',
#       'Toronto ON M5T 2N4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653610211432564,
#        'lng': -79.40219872192313}],
#      'lat': 43.653610211432564,
#      'lng': -79.40219872192313,
#      'postalCode': 'M5T 2N4',
#      'state': 'ON'},
#     'name': 'Bellevue Square Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4b9d206bf964a520e69136e3',
#     'location': {'address': 'University Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Wellesley Ave.',
#      'distance': 1181,
#      'formattedAddress': ['University Ave. (at Wellesley Ave.)',
#       'Toronto ON M5R 2E8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66394609897775,
#        'lng': -79.39217952520835}],
#      'lat': 43.66394609897775,
#      'lng': -79.39217952520835,
#      'postalCode': 'M5R 2E8',
#      'state': 'ON'},
#     'name': "Queen's Park",
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4bb79860cf2fc9b616779e02',
#     'location': {'address': '35 Wellington St. East',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1171,
#      'formattedAddress': ['35 Wellington St. East', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64804835388851,
#        'lng': -79.3751722909452}],
#      'lat': 43.64804835388851,
#      'lng': -79.3751722909452,
#      'state': 'ON'},
#     'name': 'Berczy Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'primary': True,
#       'shortName': 'Gym'}],
#     'hasPerk': False,
#     'id': '4ae04bcaf964a520857e21e3',
#     'location': {'address': '8 Park Rd',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Bloor St. E.',
#      'distance': 1953,
#      'formattedAddress': ['8 Park Rd (at Bloor St. E.)',
#       'Toronto ON M4W 3G8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67139808558312,
#        'lng': -79.3844083017028}],
#      'lat': 43.67139808558312,
#      'lng': -79.3844083017028,
#      'postalCode': 'M4W 3G8',
#      'state': 'ON'},
#     'name': 'GoodLife Fitness Toronto Bloor Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4b618500f964a52090162ae3',
#     'location': {'address': "Queen's Quay",
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Rees St.',
#      'distance': 1783,
#      'formattedAddress': ["Queen's Quay (at Rees St.)",
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63794857171933,
#        'lng': -79.38781965601113}],
#      'lat': 43.63794857171933,
#      'lng': -79.38781965601113,
#      'state': 'ON'},
#     'name': 'HTO Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4ad4c05ef964a5209ff620e3',
#     'location': {'address': '1873 Bloor St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Parkside Dr.',
#      'distance': 6195,
#      'formattedAddress': ['1873 Bloor St. W (at Parkside Dr.)',
#       'Toronto ON M6R 2Z3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6464791690415,
#        'lng': -79.46342468261719}],
#      'lat': 43.6464791690415,
#      'lng': -79.46342468261719,
#      'postalCode': 'M6R 2Z3',
#      'state': 'ON'},
#     'name': 'High Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4bb63b82941ad13a5e181fe3',
#     'location': {'address': '500 Gerrard St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at River St.',
#      'distance': 2506,
#      'formattedAddress': ['500 Gerrard St. (at River St.)',
#       'Toronto ON M5A 2H3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66604827676354,
#        'lng': -79.36094117493359}],
#      'lat': 43.66604827676354,
#      'lng': -79.36094117493359,
#      'postalCode': 'M5A 2H3',
#      'state': 'ON'},
#     'name': 'Riverdale Park West',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e5941735',
#       'name': 'Dog Run',
#       'pluralName': 'Dog Runs',
#       'primary': True,
#       'shortName': 'Dog Run'}],
#     'hasPerk': False,
#     'id': '4b23bce0f964a520ce5824e3',
#     'location': {'address': '519 Church St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Wellesley',
#      'distance': 1518,
#      'formattedAddress': ['519 Church St. (Wellesley)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66658331158984,
#        'lng': -79.3800401687622}],
#      'lat': 43.66658331158984,
#      'lng': -79.3800401687622,
#      'state': 'ON'},
#     'name': 'Cawthra Square Dog Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4c16a548955976b0cadea4f6',
#     'location': {'address': '44 Parliament Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 2056,
#      'formattedAddress': ['44 Parliament Street', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65026388338689,
#        'lng': -79.36219509081177}],
#      'lat': 43.65026388338689,
#      'lng': -79.36219509081177,
#      'state': 'ON'},
#     'name': 'Parliament Square Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4b9c2ef4f964a520785236e3',
#     'location': {'address': 'King Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Walnut',
#      'distance': 2198,
#      'formattedAddress': ['King Street West (Walnut)', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64239542050481,
#        'lng': -79.40932989120483}],
#      'lat': 43.64239542050481,
#      'lng': -79.40932989120483,
#      'state': 'ON'},
#     'name': 'Stanley Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'primary': True,
#       'shortName': 'Light Rail'}],
#     'hasPerk': False,
#     'id': '4b9177e4f964a520d2be33e3',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 360,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650735,
#        'lng': -79.386921}],
#      'lat': 43.650735,
#      'lng': -79.386921,
#      'state': 'ON'},
#     'name': 'TTC Streetcar #403 - Victoria park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'primary': True,
#       'shortName': 'Residential'}],
#     'hasPerk': False,
#     'id': '4d3a1d23325ff04db2dd1845',
#     'location': {'address': '763 Bay St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn. College St. and Gerrard St.',
#      'distance': 672,
#      'formattedAddress': ['763 Bay St. (btwn. College St. and Gerrard St.)',
#       'Toronto ON M5G 2R3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65982157793473,
#        'lng': -79.38515941616431}],
#      'lat': 43.65982157793473,
#      'lng': -79.38515941616431,
#      'postalCode': 'M5G 2R3',
#      'state': 'ON'},
#     'name': 'Residences at College Park North',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4ba5a1e2f964a5202b1839e3',
#     'location': {'address': '550 Broadview Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 3112,
#      'formattedAddress': ['550 Broadview Ave', 'Toronto ON M4K 2P1', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66995145540962,
#        'lng': -79.35549259185791}],
#      'lat': 43.66995145540962,
#      'lng': -79.35549259185791,
#      'postalCode': 'M4K 2P1',
#      'state': 'ON'},
#     'name': 'Riverdale Park East',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e5941735',
#       'name': 'Dog Run',
#       'pluralName': 'Dog Runs',
#       'primary': True,
#       'shortName': 'Dog Run'}],
#     'hasPerk': False,
#     'id': '4c34e9f7a0ced13a96fb186e',
#     'location': {'address': 'King Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Shaw Street',
#      'distance': 2243,
#      'formattedAddress': ['King Street West (Shaw Street)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64166802703168,
#        'lng': -79.40926920430412}],
#      'lat': 43.64166802703168,
#      'lng': -79.40926920430412,
#      'state': 'ON'},
#     'name': 'Stanley Park (Dog Park)',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e5941735',
#       'name': 'Dog Run',
#       'pluralName': 'Dog Runs',
#       'primary': True,
#       'shortName': 'Dog Run'}],
#     'hasPerk': False,
#     'id': '4e54574bb61c93816c084ddb',
#     'location': {'address': '51 Power St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn Adelaide St. & Richmond Ave.',
#      'distance': 1991,
#      'formattedAddress': ['51 Power St. (btwn Adelaide St. & Richmond Ave.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65465395413889,
#        'lng': -79.36250077861264}],
#      'lat': 43.65465395413889,
#      'lng': -79.36250077861264,
#      'state': 'ON'},
#     'name': "Orphan's Greenspace Dog Park",
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'primary': True,
#       'shortName': 'Medical'}],
#     'hasPerk': False,
#     'id': '59f1fde348b04e1a8368f4f4',
#     'location': {'address': '382 Yonge St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 650,
#      'formattedAddress': ['382 Yonge St', 'Toronto ON M5B 1S8', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6585279,
#        'lng': -79.3821688}],
#      'lat': 43.6585279,
#      'lng': -79.3821688,
#      'postalCode': 'M5B 1S8',
#      'state': 'ON'},
#     'name': 'Physiomed College Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e7941735',
#       'name': 'Playground',
#       'pluralName': 'Playgrounds',
#       'primary': True,
#       'shortName': 'Playground'}],
#     'hasPerk': False,
#     'id': '4bb606111344b71388da9c04',
#     'location': {'address': '530 Ontario Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Ontario & Carlton',
#      'distance': 1854,
#      'formattedAddress': ['530 Ontario Street (Ontario & Carlton)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66623107575282,
#        'lng': -79.3716312803108}],
#      'lat': 43.66623107575282,
#      'lng': -79.3716312803108,
#      'state': 'ON'},
#     'name': 'Winchester Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4b9333f1f964a520fa3a34e3',
#     'location': {'address': '711 Lake Shore Blvd. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Strachan Ave.',
#      'distance': 2610,
#      'formattedAddress': ['711 Lake Shore Blvd. W (at Strachan Ave.)',
#       'Toronto ON M5V 3T7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63455322391303,
#        'lng': -79.40540313720703}],
#      'lat': 43.63455322391303,
#      'lng': -79.40540313720703,
#      'postalCode': 'M5V 3T7',
#      'state': 'ON'},
#     'name': 'Coronation Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4b17084cf964a52038c123e3',
#     'location': {'address': '777 Victoria Park Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Danforth',
#      'distance': 9143,
#      'formattedAddress': ['777 Victoria Park Ave (at Danforth)',
#       'Toronto ON M4B 2E2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.69488264493771,
#        'lng': -79.28873509168625}],
#      'lat': 43.69488264493771,
#      'lng': -79.28873509168625,
#      'postalCode': 'M4B 2E2',
#      'state': 'ON'},
#     'name': 'Victoria Park Subway Station',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'primary': True,
#       'shortName': "Dentist's Office"}],
#     'hasPerk': False,
#     'id': '4ca32b95a73cb60cc61f1678',
#     'location': {'address': '444 Yonge St, Unit M16',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'in College Park',
#      'distance': 723,
#      'formattedAddress': ['444 Yonge St, Unit M16 (in College Park)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66000931730009,
#        'lng': -79.38390494519587}],
#      'lat': 43.66000931730009,
#      'lng': -79.38390494519587,
#      'state': 'ON'},
#     'name': 'Toothworks - College Park Dental',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4bdde5056198c9b61a1c12ff',
#     'location': {'address': '50 Fort York Blvd',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Dan Leckie Way',
#      'distance': 1869,
#      'formattedAddress': ['50 Fort York Blvd (at Dan Leckie Way)',
#       'Toronto ON M5V 3Z1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63876173785461,
#        'lng': -79.39706683158875}],
#      'lat': 43.63876173785461,
#      'lng': -79.39706683158875,
#      'postalCode': 'M5V 3Z1',
#      'state': 'ON'},
#     'name': 'Canoe Landing Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4bb3b268eb3e9521cd82cb0a',
#     'location': {'address': '120 King St E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn Church St and Jarvis St',
#      'distance': 1262,
#      'formattedAddress': ['120 King St E (btwn Church St and Jarvis St)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6504248002309,
#        'lng': -79.3723109702051}],
#      'lat': 43.6504248002309,
#      'lng': -79.3723109702051,
#      'state': 'ON'},
#     'name': 'St. James Park',
#     'referralId': 'v-1560853821'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4c030bf9f423a5938bc3cf16',
#     'location': {'address': '519 Church St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1520,
#      'formattedAddress': ['519 Church St', 'Toronto ON M4Y 2K9', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66687857011423,
#        'lng': -79.38106777601625}],
#      'lat': 43.66687857011423,
#      'lng': -79.38106777601625,
#      'postalCode': 'M4Y 2K9',
#      'state': 'ON'},
#     'name': 'Barbara Hall Park',
#     'referralId': 'v-1560853821'}]}}

# %%
# Lets assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Metro Station', 'id': '4bf58dd8d489...    False
# 1  [{'name': 'Park', 'id': '4bf58dd8d48988d163941...    False
# 2  [{'name': 'Park', 'id': '4bf58dd8d48988d163941...    False
# 3  [{'name': 'Park', 'id': '4bf58dd8d48988d163941...    False
# 4  [{'name': 'Residential Building (Apartment / C...    False
#
#                          id    location.address location.cc location.city  \
# 0  4b170e47f964a5208cc123e3  691 University Ave          CA       Toronto
# 1  4b54deadf964a520a3d027e3                 NaN          CA       Toronto
# 2  4ad4c05ef964a520bdf620e3  1053 Dundas St. W.          CA       Toronto
# 3  4bb3c91a2397b7134d9f38b3         Spadina Ave          CA       Toronto
# 4  4ad80fcef964a520a61021e3       280 Simcoe St          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada        at College St                716
# 1           Canada                  NaN                423
# 2           Canada    at Gore Vale Ave.               2271
# 3           Canada   at Wellington St W               1223
# 4           Canada   Dundas Street West                282
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4  [280 Simcoe St (Dundas Street West), Toronto O...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.64707192840234...     43.647072
# 3  [{'label': 'display', 'lat': 43.64422227794523...     43.644222
# 4  [{'label': 'display', 'lat': 43.65544241747622...     43.655442
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.413756             M5H 2N2             ON
# 3    -79.394230                 NaN             ON
# 4    -79.390056             M5T 2Y5             ON
#
#                           name    referralId venuePage.id
# 0  Queen's Park Subway Station  v-1560853821          NaN
# 1                  Grange Park  v-1560853821          NaN
# 2       Trinity Bellwoods Park  v-1560853821          NaN
# 3         Clarence Square Park  v-1560853821          NaN
# 4                One Park Lane  v-1560853821          NaN

# %%
# Lets keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                           name                                categories  \
# 0  Queen's Park Subway Station                             Metro Station
# 1                  Grange Park                                      Park
# 2       Trinity Bellwoods Park                                      Park
# 3         Clarence Square Park                                      Park
# 4                One Park Lane  Residential Building (Apartment / Condo)
#
#               address  cc     city country         crossStreet  distance  \
# 0  691 University Ave  CA  Toronto  Canada       at College St       716
# 1                 NaN  CA  Toronto  Canada                 NaN       423
# 2  1053 Dundas St. W.  CA  Toronto  Canada   at Gore Vale Ave.      2271
# 3         Spadina Ave  CA  Toronto  Canada  at Wellington St W      1223
# 4       280 Simcoe St  CA  Toronto  Canada  Dundas Street West       282
#
#                                     formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4  [280 Simcoe St (Dundas Street West), Toronto O...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 1  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 2  [{'label': 'display', 'lat': 43.64707192840234...  43.647072 -79.413756
# 3  [{'label': 'display', 'lat': 43.64422227794523...  43.644222 -79.394230
# 4  [{'label': 'display', 'lat': 43.65544241747622...  43.655442 -79.390056
#
#   postalCode state                        id
# 0    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1        NaN    ON  4b54deadf964a520a3d027e3
# 2    M5H 2N2    ON  4ad4c05ef964a520bdf620e3
# 3        NaN    ON  4bb3c91a2397b7134d9f38b3
# 4    M5T 2Y5    ON  4ad80fcef964a520a61021e3

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                    name  \
# 0           Queen's Park Subway Station
# 1                           Grange Park
# 2                Trinity Bellwoods Park
# 3                  Clarence Square Park
# 4                         One Park Lane
# 5         Crunch Fitness - College Park
# 6     St. Andrews Playground / Dog Park
# 7                  Bellevue Square Park
# 8                          Queen's Park
# 9                           Berczy Park
# 10  GoodLife Fitness Toronto Bloor Park
# 11                             HTO Park
# 12                            High Park
# 13                  Riverdale Park West
# 14              Cawthra Square Dog Park
# 15               Parliament Square Park
# 16                         Stanley Park
# 17   TTC Streetcar #403 - Victoria park
# 18     Residences at College Park North
# 19                  Riverdale Park East
# 20              Stanley Park (Dog Park)
# 21         Orphan's Greenspace Dog Park
# 22               Physiomed College Park
# 23                      Winchester Park
# 24                      Coronation Park
# 25         Victoria Park Subway Station
# 26     Toothworks - College Park Dental
# 27                   Canoe Landing Park
# 28                       St. James Park
# 29                    Barbara Hall Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                                       Park            1053 Dundas St. W.
# 3                                       Park                   Spadina Ave
# 4   Residential Building (Apartment / Condo)                 280 Simcoe St
# 5                       Gym / Fitness Center              382 Yonge Street
# 6                                       Park      450 Adelaide Street West
# 7                                       Park  btwn Bellevue & Augusta Ave.
# 8                                       Park               University Ave.
# 9                                       Park        35 Wellington St. East
# 10                                       Gym                     8 Park Rd
# 11                                      Park                  Queen's Quay
# 12                                      Park              1873 Bloor St. W
# 13                                      Park               500 Gerrard St.
# 14                                   Dog Run                519 Church St.
# 15                                      Park          44 Parliament Street
# 16                                      Park              King Street West
# 17                        Light Rail Station                           NaN
# 18  Residential Building (Apartment / Condo)                   763 Bay St.
# 19                                      Park             550 Broadview Ave
# 20                                   Dog Run              King Street West
# 21                                   Dog Run                  51 Power St.
# 22                            Medical Center                  382 Yonge St
# 23                                Playground            530 Ontario Street
# 24                                      Park        711 Lake Shore Blvd. W
# 25                             Metro Station         777 Victoria Park Ave
# 26                          Dentist's Office        444 Yonge St, Unit M16
# 27                                      Park             50 Fort York Blvd
# 28                                      Park                 120 King St E
# 29                                      Park                 519 Church St
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.647072 -79.413756    M5H 2N2    ON
# 3   43.644222 -79.394230        NaN    ON
# 4   43.655442 -79.390056    M5T 2Y5    ON
# 5   43.659263 -79.382632    M5G 1S8    ON
# 6   43.647388 -79.398752        NaN    ON
# 7   43.653610 -79.402199    M5T 2N4    ON
# 8   43.663946 -79.392180    M5R 2E8    ON
# 9   43.648048 -79.375172        NaN    ON
# 10  43.671398 -79.384408    M4W 3G8    ON
# 11  43.637949 -79.387820        NaN    ON
# 12  43.646479 -79.463425    M6R 2Z3    ON
# 13  43.666048 -79.360941    M5A 2H3    ON
# 14  43.666583 -79.380040        NaN    ON
# 15  43.650264 -79.362195        NaN    ON
# 16  43.642395 -79.409330        NaN    ON
# 17  43.650735 -79.386921        NaN    ON
# 18  43.659822 -79.385159    M5G 2R3    ON
# 19  43.669951 -79.355493    M4K 2P1    ON
# 20  43.641668 -79.409269        NaN    ON
# 21  43.654654 -79.362501        NaN    ON
# 22  43.658528 -79.382169    M5B 1S8    ON
# 23  43.666231 -79.371631        NaN    ON
# 24  43.634553 -79.405403    M5V 3T7    ON
# 25  43.694883 -79.288735    M4B 2E2    ON
# 26  43.660009 -79.383905        NaN    ON
# 27  43.638762 -79.397067    M5V 3Z1    ON
# 28  43.650425 -79.372311        NaN    ON
# 29  43.666879 -79.381068    M4Y 2K9    ON

# %%
# Lets delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                    name  \
# 0           Queen's Park Subway Station
# 2                Trinity Bellwoods Park
# 4                         One Park Lane
# 5         Crunch Fitness - College Park
# 7                  Bellevue Square Park
# 8                          Queen's Park
# 10  GoodLife Fitness Toronto Bloor Park
# 12                            High Park
# 13                  Riverdale Park West
# 18     Residences at College Park North
# 19                  Riverdale Park East
# 22               Physiomed College Park
# 24                      Coronation Park
# 25         Victoria Park Subway Station
# 27                   Canoe Landing Park
# 29                    Barbara Hall Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 2                                       Park            1053 Dundas St. W.
# 4   Residential Building (Apartment / Condo)                 280 Simcoe St
# 5                       Gym / Fitness Center              382 Yonge Street
# 7                                       Park  btwn Bellevue & Augusta Ave.
# 8                                       Park               University Ave.
# 10                                       Gym                     8 Park Rd
# 12                                      Park              1873 Bloor St. W
# 13                                      Park               500 Gerrard St.
# 18  Residential Building (Apartment / Condo)                   763 Bay St.
# 19                                      Park             550 Broadview Ave
# 22                            Medical Center                  382 Yonge St
# 24                                      Park        711 Lake Shore Blvd. W
# 25                             Metro Station         777 Victoria Park Ave
# 27                                      Park             50 Fort York Blvd
# 29                                      Park                 519 Church St
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 2   43.647072 -79.413756    M5H 2N2    ON
# 4   43.655442 -79.390056    M5T 2Y5    ON
# 5   43.659263 -79.382632    M5G 1S8    ON
# 7   43.653610 -79.402199    M5T 2N4    ON
# 8   43.663946 -79.392180    M5R 2E8    ON
# 10  43.671398 -79.384408    M4W 3G8    ON
# 12  43.646479 -79.463425    M6R 2Z3    ON
# 13  43.666048 -79.360941    M5A 2H3    ON
# 18  43.659822 -79.385159    M5G 2R3    ON
# 19  43.669951 -79.355493    M4K 2P1    ON
# 22  43.658528 -79.382169    M5B 1S8    ON
# 24  43.634553 -79.405403    M5V 3T7    ON
# 25  43.694883 -79.288735    M4B 2E2    ON
# 27  43.638762 -79.397067    M5V 3Z1    ON
# 29  43.666879 -79.381068    M4Y 2K9    ON

# %%
# Lets delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 2   Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 7     Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 8             Queen's Park       Park               University Ave.
# 12               High Park       Park              1873 Bloor St. W
# 13     Riverdale Park West       Park               500 Gerrard St.
# 19     Riverdale Park East       Park             550 Broadview Ave
# 24         Coronation Park       Park        711 Lake Shore Blvd. W
# 27      Canoe Landing Park       Park             50 Fort York Blvd
# 29       Barbara Hall Park       Park                 519 Church St
#
#           lat        lng postalCode state
# 2   43.647072 -79.413756    M5H 2N2    ON
# 7   43.653610 -79.402199    M5T 2N4    ON
# 8   43.663946 -79.392180    M5R 2E8    ON
# 12  43.646479 -79.463425    M6R 2Z3    ON
# 13  43.666048 -79.360941    M5A 2H3    ON
# 19  43.669951 -79.355493    M4K 2P1    ON
# 24  43.634553 -79.405403    M5V 3T7    ON
# 27  43.638762 -79.397067    M5V 3Z1    ON
# 29  43.666879 -79.381068    M4Y 2K9    ON

# %%
# Lets search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=J1F24KJMK4YD0QK00HGFLEOBJRKH5XGLOJBPY4DLKSQGPKK0&client_secret=LAJR2Q0ZUAGDBFPRY4N3AQF50NBK0WSBYZX0RVFMHZWP5JU0&ll=43.653963,-79.387207&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Lets send the GET Request and examine the results
Rresults = requests.get(url).json()
Rresults
# Out:
# {'meta': {'code': 200, 'requestId': '5d08bd81733dc4002bb305ba'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a52048f720e3',
#     'location': {'address': '110 Chestnut Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 145,
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'postalCode': 'M5G 1R3',
#      'state': 'ON'},
#     'name': 'Hemispheres Restaurant & Bistro',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'primary': True,
#       'shortName': 'Dim Sum'}],
#     'hasPerk': False,
#     'id': '4ad4c060f964a5207ff720e3',
#     'location': {'address': '323 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': "at D'Arcy St.",
#      'distance': 922,
#      'formattedAddress': ["323 Spadina Ave. (at D'Arcy St.)",
#       'Toronto ON M5T 2E9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65431754076345,
#        'lng': -79.39864998374682}],
#      'lat': 43.65431754076345,
#      'lng': -79.39864998374682,
#      'neighborhood': 'Kensington Market',
#      'postalCode': 'M5T 2E9',
#      'state': 'ON'},
#     'name': 'Rol San Restaurant 龍笙棧',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b223f5af964a520ba4424e3',
#     'location': {'address': '225 Frnt St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1039,
#      'formattedAddress': ['225 Frnt St W', 'Toronto ON M5V 2X3', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644749195919346,
#        'lng': -79.38511295085902}],
#      'lat': 43.644749195919346,
#      'lng': -79.38511295085902,
#      'neighborhood': 'Entertainment District',
#      'postalCode': 'M5V 2X3',
#      'state': 'ON'},
#     'name': 'Azure Restaurant & Bar',
#     'referralId': 'v-1560853889',
#     'venuePage': {'id': '136175835'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a52006f620e3',
#     'location': {'address': '37 King Street East',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Le Meridien King Edward Hotel',
#      'distance': 1011,
#      'formattedAddress': ['37 King Street East (at Le Meridien King Edward Hotel)',
#       'Toronto ON M5C 1E9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64929834396347,
#        'lng': -79.37643067251867}],
#      'lat': 43.64929834396347,
#      'lng': -79.37643067251867,
#      'postalCode': 'M5C 1E9',
#      'state': 'ON'},
#     'name': "Victoria's Restaurant",
#     'referralId': 'v-1560853889',
#     'venuePage': {'id': '498556908'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'primary': True,
#       'shortName': 'Dim Sum'}],
#     'hasPerk': False,
#     'id': '4b072e9df964a52009f922e3',
#     'location': {'address': '280 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Dundas St. W.',
#      'distance': 892,
#      'formattedAddress': ['280 Spadina Ave. (at Dundas St. W.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65278331265585,
#        'lng': -79.39817372355205}],
#      'lat': 43.65278331265585,
#      'lng': -79.39817372355205,
#      'state': 'ON'},
#     'name': 'Sky Dragon Chinese Restaurant 龍翔酒樓',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'primary': True,
#       'shortName': 'Wine Bar'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a520dff520e3',
#     'location': {'address': '301 Front St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': '301 Front St. W',
#      'distance': 1271,
#      'formattedAddress': ['301 Front St W (301 Front St. W)',
#       'Toronto ON M5V 2T6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642537317144566,
#        'lng': -79.38704201569328}],
#      'lat': 43.642537317144566,
#      'lng': -79.38704201569328,
#      'postalCode': 'M5V 2T6',
#      'state': 'ON'},
#     'name': '360 Restaurant',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'primary': True,
#       'shortName': 'Noodles'}],
#     'hasPerk': False,
#     'id': '4b266f05f964a520657b24e3',
#     'location': {'address': '266 Spadina Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Willison Sq',
#      'distance': 892,
#      'formattedAddress': ['266 Spadina Ave (at Willison Sq)',
#       'Toronto ON M5T 2E4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6522783893466,
#        'lng': -79.39803917534071}],
#      'lat': 43.6522783893466,
#      'lng': -79.39803917534071,
#      'postalCode': 'M5T 2E4',
#      'state': 'ON'},
#     'name': 'Goldstone Noodle Restaurant 金石',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4ad4c05df964a5203ff620e3',
#     'location': {'address': '30 Mercer Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at John St',
#      'distance': 979,
#      'formattedAddress': ['30 Mercer Street (at John St)',
#       'Toronto ON M5V 1H3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64563436248102,
#        'lng': -79.39112538566908}],
#      'lat': 43.64563436248102,
#      'lng': -79.39112538566908,
#      'postalCode': 'M5V 1H3',
#      'state': 'ON'},
#     'name': 'Victor Restaurant & Bar',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4ae29812f964a520288f21e3',
#     'location': {'address': '309 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': "btwn Dundas St. W & D'Arcy St.",
#      'distance': 896,
#      'formattedAddress': ["309 Spadina Ave. (btwn Dundas St. W & D'Arcy St.)",
#       'Toronto ON M5T 2E6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65386562507761,
#        'lng': -79.39833353339202}],
#      'lat': 43.65386562507761,
#      'lng': -79.39833353339202,
#      'postalCode': 'M5T 2E6',
#      'state': 'ON'},
#     'name': 'Swatow Restaurant 汕頭小食家',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '5c33c7cd8194fc002c66f72e',
#     'location': {'address': '261 Spadina Avenue. Upper level',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 845,
#      'formattedAddress': ['261 Spadina Avenue. Upper level',
#       'Toronto ON M5T 2E3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652487830335545,
#        'lng': -79.39750134944916}],
#      'lat': 43.652487830335545,
#      'lng': -79.39750134944916,
#      'postalCode': 'M5T 2E3',
#      'state': 'ON'},
#     'name': 'Green Tea Restaurant Downtown',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4b074bb1f964a52077fb22e3',
#     'location': {'address': '353 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 953,
#      'formattedAddress': ['353 Spadina Ave.', 'Toronto ON M5T 2G3', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65533674412141,
#        'lng': -79.39889716243826}],
#      'lat': 43.65533674412141,
#      'lng': -79.39889716243826,
#      'postalCode': 'M5T 2G3',
#      'state': 'ON'},
#     'name': 'New Sky Restaurant 小沙田食家',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4d06c1ccc2e53704428cc567',
#     'location': {'address': '476 Dundas St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Huron',
#      'distance': 767,
#      'formattedAddress': ['476 Dundas St. (Huron)', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6531846832903,
#        'lng': -79.3966766276528}],
#      'lat': 43.6531846832903,
#      'lng': -79.3966766276528,
#      'state': 'ON'},
#     'name': 'North-East Chinese Restaurant 華北美食',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4ada5d5bf964a520e92121e3',
#     'location': {'address': '35 Church St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Front St E',
#      'distance': 1229,
#      'formattedAddress': ['35 Church St (at Front St E)',
#       'Toronto ON M5E 1T3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64882370529773,
#        'lng': -79.37370210886002}],
#      'lat': 43.64882370529773,
#      'lng': -79.37370210886002,
#      'postalCode': 'M5E 1T3',
#      'state': 'ON'},
#     'name': 'The Hot House Restaurant & Bar',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'primary': True,
#       'shortName': 'Caribbean'}],
#     'hasPerk': False,
#     'id': '5b1c3098f96b2c002c5eb0c5',
#     'location': {'address': '405 Spadina Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'College St',
#      'distance': 1019,
#      'formattedAddress': ['405 Spadina Ave (College St)',
#       'Toronto ON M5T 2G6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656794,
#        'lng': -79.399251}],
#      'lat': 43.656794,
#      'lng': -79.399251,
#      'postalCode': 'M5T 2G6',
#      'state': 'ON'},
#     'name': "Tasty's Caribbean Restaurant & Catering",
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'primary': True,
#       'shortName': 'Korean'}],
#     'hasPerk': False,
#     'id': '4ba2d00cf964a5203e1b38e3',
#     'location': {'address': '8 St Andrew St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Spadina Ave.',
#      'distance': 972,
#      'formattedAddress': ['8 St Andrew St. (at Spadina Ave.)',
#       'Toronto ON M5T 1K6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654306552286656,
#        'lng': -79.3992765578534}],
#      'lat': 43.654306552286656,
#      'lng': -79.3992765578534,
#      'postalCode': 'M5T 1K6',
#      'state': 'ON'},
#     'name': 'Ka Chi Korean Restaurant',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4aef8854f964a5201cd921e3',
#     'location': {'address': '287 King St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at John St.',
#      'distance': 857,
#      'formattedAddress': ['287 King St. W (at John St.)',
#       'Toronto ON M5V 1J5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646462521503445,
#        'lng': -79.38964414801342}],
#      'lat': 43.646462521503445,
#      'lng': -79.38964414801342,
#      'postalCode': 'M5V 1J5',
#      'state': 'ON'},
#     'name': 'Aroma Fine Indian Restaurant',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4b2027b5f964a520f82d24e3',
#     'location': {'address': '195 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at University Ave',
#      'distance': 107,
#      'formattedAddress': ['195 Dundas St W (at University Ave)',
#       'Toronto ON M5G 1C7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492521335936,
#        'lng': -79.38708916106386}],
#      'lat': 43.65492521335936,
#      'lng': -79.38708916106386,
#      'postalCode': 'M5G 1C7',
#      'state': 'ON'},
#     'name': 'Hong Shing Chinese Restaurant',
#     'referralId': 'v-1560853889',
#     'venuePage': {'id': '60327598'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'primary': True,
#       'shortName': 'Event Space'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a520cef520e3',
#     'location': {'address': '100 Cumberland Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Bellair St',
#      'distance': 1849,
#      'formattedAddress': ['100 Cumberland Street (Bellair St)',
#       'Toronto ON M5R 1A6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67034226367314,
#        'lng': -79.39104050451753}],
#      'lat': 43.67034226367314,
#      'lng': -79.39104050451753,
#      'postalCode': 'M5R 1A6',
#      'state': 'ON'},
#     'name': 'Sassafraz | Cafe | Restaurant | Private Events',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b4d3b51f964a520e4ce26e3',
#     'location': {'address': '90 Bloor St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Yonge St.',
#      'distance': 1858,
#      'formattedAddress': ['90 Bloor St. (Yonge St.)',
#       'Toronto ON M4W 1A7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67057375344845,
#        'lng': -79.38485582052517}],
#      'lat': 43.67057375344845,
#      'lng': -79.38485582052517,
#      'postalCode': 'M4W 1A7',
#      'state': 'ON'},
#     'name': 'Matisse Restaurant And Bar',
#     'referralId': 'v-1560853889',
#     'venuePage': {'id': '83923512'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'primary': True,
#       'shortName': 'New American'}],
#     'hasPerk': False,
#     'id': '4ada6d8df964a520832221e3',
#     'location': {'address': '72 Ossington Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Queen St. W',
#      'distance': 2755,
#      'formattedAddress': ['72 Ossington Ave. (Queen St. W)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64585979013257,
#        'lng': -79.41953208988866}],
#      'lat': 43.64585979013257,
#      'lng': -79.41953208988866,
#      'state': 'ON'},
#     'name': 'Union Restaurant',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a5200bf720e3',
#     'location': {'address': '346-348 Spadina Avenue',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 960,
#      'formattedAddress': ['346-348 Spadina Avenue',
#       'Toronto ON M5T 2G2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654219,
#        'lng': -79.399125}],
#      'lat': 43.654219,
#      'lng': -79.399125,
#      'postalCode': 'M5T 2G2',
#      'state': 'ON'},
#     'name': 'Bright Pearl Seafood Restaurant',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a520cdf520e3',
#     'location': {'address': '563 Bloor St West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Bathurst St',
#      'distance': 2284,
#      'formattedAddress': ['563 Bloor St West (Bathurst St)',
#       'Toronto ON M5S 1Y6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.665179618013326,
#        'lng': -79.41096552569321}],
#      'lat': 43.665179618013326,
#      'lng': -79.41096552569321,
#      'postalCode': 'M5S 1Y6',
#      'state': 'ON'},
#     'name': 'Insomnia Restaurant and Lounge',
#     'referralId': 'v-1560853889',
#     'venuePage': {'id': '51631703'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'primary': True,
#       'shortName': 'Diner'}],
#     'hasPerk': False,
#     'id': '4b22e814f964a520175024e3',
#     'location': {'address': '1132 Dundas St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Ossington Ave.',
#      'distance': 2719,
#      'formattedAddress': ['1132 Dundas St. W (at Ossington Ave.)',
#       'Toronto ON M6J 1X2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64943515996231,
#        'lng': -79.42039021958406}],
#      'lat': 43.64943515996231,
#      'lng': -79.42039021958406,
#      'postalCode': 'M6J 1X2',
#      'state': 'ON'},
#     'name': 'The Lakeview Restaurant',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'primary': True,
#       'shortName': 'New American'}],
#     'hasPerk': False,
#     'id': '4b02a076f964a520234922e3',
#     'location': {'address': '116 Yorkville Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Hazelton Ave.',
#      'distance': 1937,
#      'formattedAddress': ['116 Yorkville Ave (at Hazelton Ave.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.670809368275535,
#        'lng': -79.39327240013003}],
#      'lat': 43.670809368275535,
#      'lng': -79.39327240013003,
#      'state': 'ON'},
#     'name': 'ONE Restaurant/Lounge',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '50ca02c0245f2d4aa8c2b313',
#     'location': {'address': '145 Richmond Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Hilton Toronto',
#      'distance': 458,
#      'formattedAddress': ['145 Richmond Street West (Hilton Toronto)',
#       'Toronto ON M5H 2L2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650009987649646,
#        'lng': -79.38560774268629}],
#      'lat': 43.650009987649646,
#      'lng': -79.38560774268629,
#      'postalCode': 'M5H 2L2',
#      'state': 'ON'},
#     'name': 'Tundra Restaurant',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'primary': True,
#       'shortName': 'New American'}],
#     'hasPerk': False,
#     'id': '4cc3a79bbde8f04d0ddba64b',
#     'location': {'address': '293 Palmerston Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at College St.',
#      'distance': 1841,
#      'formattedAddress': ['293 Palmerston Ave. (at College St.)',
#       'Toronto ON M6J 2J3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655765,
#        'lng': -79.409929}],
#      'lat': 43.655765,
#      'lng': -79.409929,
#      'postalCode': 'M6J 2J3',
#      'state': 'ON'},
#     'name': 'Woodlot Restaurant & Bakery',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4bd47e6fcfa7b7139f2924da',
#     'location': {'address': '389 Church St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Carlton St.',
#      'distance': 1052,
#      'formattedAddress': ['389 Church St. (at Carlton St.)',
#       'Toronto ON M5B',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.661500159065305,
#        'lng': -79.3793192447337}],
#      'lat': 43.661500159065305,
#      'lng': -79.3793192447337,
#      'postalCode': 'M5B',
#      'state': 'ON'},
#     'name': 'Studio Restaurant',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '537e313d498e9e9e015f3018',
#     'location': {'address': '299 Adelaide St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Peter St',
#      'distance': 769,
#      'formattedAddress': ['299 Adelaide St W (Peter St)',
#       'Toronto ON M5V 1P7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64764401408166,
#        'lng': -79.3910688649793}],
#      'lat': 43.64764401408166,
#      'lng': -79.3910688649793,
#      'postalCode': 'M5V 1P7',
#      'state': 'ON'},
#     'name': 'Montecito Restaurant',
#     'referralId': 'v-1560853889',
#     'venuePage': {'id': '145052232'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4bce1ec0cc8cd13a9ac8c3cf',
#     'location': {'address': '2A Kensington Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas St. W',
#      'distance': 1035,
#      'formattedAddress': ['2A Kensington Ave. (Dundas St. W)',
#       'Toronto ON M5T 2J7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65280330843737,
#        'lng': -79.39995806711424}],
#      'lat': 43.65280330843737,
#      'lng': -79.39995806711424,
#      'postalCode': 'M5T 2J7',
#      'state': 'ON'},
#     'name': 'Kensington Cornerstone Restaurant',
#     'referralId': 'v-1560853889'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'primary': True,
#       'shortName': 'Thai'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a52018f720e3',
#     'location': {'address': '338 Jarvis St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'north of Carlton Street',
#      'distance': 1284,
#      'formattedAddress': ['338 Jarvis St. (north of Carlton Street)',
#       'Toronto ON M4Y 2G6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66277006654972,
#        'lng': -79.37689434011018}],
#      'lat': 43.66277006654972,
#      'lng': -79.37689434011018,
#      'postalCode': 'M4Y 2G6',
#      'state': 'ON'},
#     'name': 'Cottage Restaurant & Lounge',
#     'referralId': 'v-1560853889'}]}}

# %%
# Lets assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'American Restaurant', 'id': '4bf58d...    False
# 1  [{'name': 'Dim Sum Restaurant', 'id': '4bf58dd...    False
# 2  [{'name': 'Restaurant', 'id': '4bf58dd8d48988d...    False
# 3  [{'name': 'Restaurant', 'id': '4bf58dd8d48988d...    False
# 4  [{'name': 'Dim Sum Restaurant', 'id': '4bf58dd...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 2  4b223f5af964a520ba4424e3        225 Frnt St W          CA       Toronto
# 3  4ad4c05cf964a52006f620e3  37 King Street East          CA       Toronto
# 4  4b072e9df964a52009f922e3     280 Spadina Ave.          CA       Toronto
#
#   location.country              location.crossStreet  location.distance  \
# 0           Canada                               NaN                145
# 1           Canada                     at D'Arcy St.                922
# 2           Canada                               NaN               1039
# 3           Canada  at Le Meridien King Edward Hotel               1011
# 4           Canada                  at Dundas St. W.                892
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 2        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 3  [37 King Street East (at Le Meridien King Edwa...
# 4  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 2  [{'label': 'display', 'lat': 43.64474919591934...     43.644749
# 3  [{'label': 'display', 'lat': 43.64929834396347...     43.649298
# 4  [{'label': 'display', 'lat': 43.65278331265585...     43.652783
#
#    location.lng   location.neighborhood location.postalCode location.state  \
# 0    -79.385931                     NaN             M5G 1R3             ON
# 1    -79.398650       Kensington Market             M5T 2E9             ON
# 2    -79.385113  Entertainment District             M5V 2X3             ON
# 3    -79.376431                     NaN             M5C 1E9             ON
# 4    -79.398174                     NaN                 NaN             ON
#
#                                  name    referralId venuePage.id
# 0     Hemispheres Restaurant & Bistro  v-1560853889          NaN
# 1              Rol San Restaurant 龍笙棧  v-1560853889          NaN
# 2              Azure Restaurant & Bar  v-1560853889    136175835
# 3               Victoria's Restaurant  v-1560853889    498556908
# 4  Sky Dragon Chinese Restaurant 龍翔酒樓  v-1560853889          NaN

# %%
# Lets keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                  name           categories  \
# 0     Hemispheres Restaurant & Bistro  American Restaurant
# 1              Rol San Restaurant 龍笙棧   Dim Sum Restaurant
# 2              Azure Restaurant & Bar           Restaurant
# 3               Victoria's Restaurant           Restaurant
# 4  Sky Dragon Chinese Restaurant 龍翔酒樓   Dim Sum Restaurant
#
#                address  cc     city country                       crossStreet  \
# 0  110 Chestnut Street  CA  Toronto  Canada                               NaN
# 1     323 Spadina Ave.  CA  Toronto  Canada                     at D'Arcy St.
# 2        225 Frnt St W  CA  Toronto  Canada                               NaN
# 3  37 King Street East  CA  Toronto  Canada  at Le Meridien King Edward Hotel
# 4     280 Spadina Ave.  CA  Toronto  Canada                  at Dundas St. W.
#
#    distance                                   formattedAddress  \
# 0       145  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1       922  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 2      1039        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 3      1011  [37 King Street East (at Le Meridien King Edwa...
# 4       892  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 1  [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
# 2  [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
# 3  [{'label': 'display', 'lat': 43.64929834396347...  43.649298 -79.376431
# 4  [{'label': 'display', 'lat': 43.65278331265585...  43.652783 -79.398174
#
#              neighborhood postalCode state                        id
# 0                     NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1       Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 2  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3
# 3                     NaN    M5C 1E9    ON  4ad4c05cf964a52006f620e3
# 4                     NaN        NaN    ON  4b072e9df964a52009f922e3

# %%
# Lets delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 2                           Azure Restaurant & Bar               Restaurant
# 3                            Victoria's Restaurant               Restaurant
# 4               Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 5                                   360 Restaurant                 Wine Bar
# 6                   Goldstone Noodle Restaurant 金石             Noodle House
# 7                          Victor Restaurant & Bar                      Bar
# 8                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 9                    Green Tea Restaurant Downtown       Chinese Restaurant
# 10                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 11              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 12                  The Hot House Restaurant & Bar      American Restaurant
# 13         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15                    Aroma Fine Indian Restaurant        Indian Restaurant
# 16                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 17  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 18                      Matisse Restaurant And Bar               Restaurant
# 19                                Union Restaurant  New American Restaurant
# 20                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 21                  Insomnia Restaurant and Lounge               Restaurant
# 22                         The Lakeview Restaurant                    Diner
# 23                           ONE Restaurant/Lounge  New American Restaurant
# 24                               Tundra Restaurant               Restaurant
# 25                     Woodlot Restaurant & Bakery  New American Restaurant
# 26                               Studio Restaurant           Breakfast Spot
# 27                            Montecito Restaurant               Restaurant
# 28               Kensington Cornerstone Restaurant           Breakfast Spot
# 29                     Cottage Restaurant & Lounge          Thai Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 2                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 3               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 4                  280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 5                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 6                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 7                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 8                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 9   261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 10                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 11                   476 Dundas St.  43.653185 -79.396677        NaN    ON
# 12                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 13                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 16                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 17            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 18                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 19                72 Ossington Ave.  43.645860 -79.419532        NaN    ON
# 20           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 21                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 22                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 23                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 24         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 25              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 26                   389 Church St.  43.661500 -79.379319        M5B    ON
# 27                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 28               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 29                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON

# %%
# Lets delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 2                           Azure Restaurant & Bar               Restaurant
# 3                            Victoria's Restaurant               Restaurant
# 5                                   360 Restaurant                 Wine Bar
# 6                   Goldstone Noodle Restaurant 金石             Noodle House
# 7                          Victor Restaurant & Bar                      Bar
# 8                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 9                    Green Tea Restaurant Downtown       Chinese Restaurant
# 10                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 12                  The Hot House Restaurant & Bar      American Restaurant
# 13         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15                    Aroma Fine Indian Restaurant        Indian Restaurant
# 16                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 17  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 18                      Matisse Restaurant And Bar               Restaurant
# 20                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 21                  Insomnia Restaurant and Lounge               Restaurant
# 22                         The Lakeview Restaurant                    Diner
# 24                               Tundra Restaurant               Restaurant
# 25                     Woodlot Restaurant & Bakery  New American Restaurant
# 26                               Studio Restaurant           Breakfast Spot
# 27                            Montecito Restaurant               Restaurant
# 28               Kensington Cornerstone Restaurant           Breakfast Spot
# 29                     Cottage Restaurant & Lounge          Thai Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 2                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 3               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 5                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 6                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 7                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 8                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 9   261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 10                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 12                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 13                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 16                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 17            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 18                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 20           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 21                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 22                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 24         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 25              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 26                   389 Church St.  43.661500 -79.379319        M5B    ON
# 27                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 28               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 29                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON

# %%
# Lets search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=J1F24KJMK4YD0QK00HGFLEOBJRKH5XGLOJBPY4DLKSQGPKK0&client_secret=LAJR2Q0ZUAGDBFPRY4N3AQF50NBK0WSBYZX0RVFMHZWP5JU0&ll=43.653963,-79.387207&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Lets send the GET Request and examine the results
cresults = requests.get(url).json()
cresults
# Out:
# {'meta': {'code': 200, 'requestId': '5d08bdbc733dc4002bb462a6'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'primary': True,
#       'shortName': 'Fast Food'}],
#     'hasPerk': False,
#     'id': '4f9165bde4b04fef0087e4e2',
#     'location': {'address': 'The Hospital for Sick Children (SickKids)',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 372,
#      'formattedAddress': ['The Hospital for Sick Children (SickKids)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65720930549997,
#        'lng': -79.38606324056798}],
#      'lat': 43.65720930549997,
#      'lng': -79.38606324056798,
#      'state': 'ON'},
#     'name': 'Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'primary': True,
#       'shortName': 'Asian'}],
#     'hasPerk': False,
#     'id': '528e99a211d262edc3708a6f',
#     'location': {'address': '388 Spadina Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Nassau St',
#      'distance': 977,
#      'formattedAddress': ['388 Spadina Ave (at Nassau St)',
#       'Toronto ON M5T 2G5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65545427446646,
#        'lng': -79.3991632002347}],
#      'lat': 43.65545427446646,
#      'lng': -79.3991632002347,
#      'postalCode': 'M5T 2G5',
#      'state': 'ON'},
#     'name': 'Stay Cafeteria 慢走',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'primary': True,
#       'shortName': 'Mexican'}],
#     'hasPerk': False,
#     'id': '56b2c90a498e9f0e73d6bed6',
#     'location': {'address': '974 College St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 3260,
#      'formattedAddress': ['974 College St', 'Toronto ON M6H 1A5', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65341883567197,
#        'lng': -79.42767758591519}],
#      'lat': 43.65341883567197,
#      'lng': -79.42767758591519,
#      'postalCode': 'M6H 1A5',
#      'state': 'ON'},
#     'name': 'Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '4ec2b68a8231a83de8c45191',
#     'location': {'address': '100 McCaul St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Second Floor',
#      'distance': 389,
#      'formattedAddress': ['100 McCaul St. (Second Floor)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65278016892648,
#        'lng': -79.39176169040549}],
#      'lat': 43.65278016892648,
#      'lng': -79.39176169040549,
#      'state': 'ON'},
#     'name': 'OCAD Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '53bd6dfe498e6c1d3bc9333e',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 260,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655657,
#        'lng': -79.389443}],
#      'lat': 43.655657,
#      'lng': -79.389443,
#      'state': 'ON'},
#     'name': 'Industrial Alliance Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'primary': True,
#       'shortName': 'Desserts'}],
#     'hasPerk': False,
#     'id': '556f826b498e07f469e6bf1f',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 431,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654178619384766,
#        'lng': -79.3925552368164}],
#      'lat': 43.654178619384766,
#      'lng': -79.3925552368164},
#     'name': 'Dears Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '524f1c8f498e983dde61ada0',
#     'location': {'address': '89 Chestnut Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 687,
#      'formattedAddress': ['89 Chestnut Street', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648231,
#        'lng': -79.384045}],
#      'lat': 43.648231,
#      'lng': -79.384045,
#      'state': 'ON'},
#     'name': 'Chestnut Tree Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '4b57256bf964a520332828e3',
#     'location': {'address': 'Yonge',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas',
#      'distance': 574,
#      'formattedAddress': ['Yonge (Dundas)', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656037859093914,
#        'lng': -79.38067188503244}],
#      'lat': 43.656037859093914,
#      'lng': -79.38067188503244,
#      'state': 'ON'},
#     'name': 'Sears Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '4e7641cdcc3fc1186ed1000a',
#     'location': {'address': '131 Farnham Avenue',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 3343,
#      'formattedAddress': ['131 Farnham Avenue',
#       'Toronto ON M4V 1H7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.68300316722829,
#        'lng': -79.3978151679039}],
#      'lat': 43.68300316722829,
#      'lng': -79.3978151679039,
#      'postalCode': 'M4V 1H7',
#      'state': 'ON'},
#     'name': 'De La Salle College Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '507d8f04e4b0ee8339e70ccd',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 840,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.660259819542816,
#        'lng': -79.39297670479313}],
#      'lat': 43.660259819542816,
#      'lng': -79.39297670479313,
#      'state': 'ON'},
#     'name': 'Med Sci Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '4f187cbee4b0b34551e99f8d',
#     'location': {'address': '350 Victoria St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Gould St.',
#      'distance': 918,
#      'formattedAddress': ['350 Victoria St. (Gould St.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65847495106884,
#        'lng': -79.37765316062669}],
#      'lat': 43.65847495106884,
#      'lng': -79.37765316062669,
#      'state': 'ON'},
#     'name': 'Ryerson Hub Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '4e7792bb45ddd43240ad83dc',
#     'location': {'address': '555 University Avenue',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1014,
#      'formattedAddress': ['555 University Avenue', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657583774305685,
#        'lng': -79.37565162062124}],
#      'lat': 43.657583774305685,
#      'lng': -79.37565162062124,
#      'state': 'ON'},
#     'name': 'SickKids Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '524d852e498ee3a28a0dc528',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 1031,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6632117940897,
#        'lng': -79.38806157090927}],
#      'lat': 43.6632117940897,
#      'lng': -79.38806157090927},
#     'name': 'Macdonald Block Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '4ea850c9cc21adeb9941eafc',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1873,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66990371100761,
#        'lng': -79.37974848984038}],
#      'lat': 43.66990371100761,
#      'lng': -79.37974848984038,
#      'state': 'ON'},
#     'name': 'Rogers Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '4da3461f0f578cfad263b518',
#     'location': {'address': '130 St. George St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Harbord',
#      'distance': 1579,
#      'formattedAddress': ['130 St. George St. (Harbord)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66486391321585,
#        'lng': -79.39976619717828}],
#      'lat': 43.66486391321585,
#      'lng': -79.39976619717828,
#      'state': 'ON'},
#     'name': 'Robarts Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '4dc40d1645dd2645524c51c4',
#     'location': {'address': '1 Mount Pleasant',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1861,
#      'formattedAddress': ['1 Mount Pleasant', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66980094410764,
#        'lng': -79.37979018052529}],
#      'lat': 43.66980094410764,
#      'lng': -79.37979018052529,
#      'state': 'ON'},
#     'name': 'OMP Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '4c12603ca9c220a19cd3539d',
#     'location': {'address': '200 Bloor Street E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1989,
#      'formattedAddress': ['200 Bloor Street E', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67141124340467,
#        'lng': -79.3818485560509}],
#      'lat': 43.67141124340467,
#      'lng': -79.3818485560509,
#      'state': 'ON'},
#     'name': 'Choices Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'primary': True,
#       'shortName': 'High School'}],
#     'hasPerk': False,
#     'id': '4f27e889e4b04d36e13d9efc',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 7756,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.721731539909015,
#        'lng': -79.4096004557459}],
#      'lat': 43.721731539909015,
#      'lng': -79.4096004557459},
#     'name': 'Cafeteria, Lawrence Park Collegiate',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/african_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c8941735',
#       'name': 'African Restaurant',
#       'pluralName': 'African Restaurants',
#       'primary': True,
#       'shortName': 'African'}],
#     'hasPerk': False,
#     'id': '4e36c886d22d86185a799b59',
#     'location': {'address': 'Bloor',
#      'cc': 'CA',
#      'country': 'Canada',
#      'crossStreet': 'Ossington',
#      'distance': 3059,
#      'formattedAddress': ['Bloor (Ossington)', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66075927808355,
#        'lng': -79.42401789232505}],
#      'lat': 43.66075927808355,
#      'lng': -79.42401789232505},
#     'name': 'Kasala Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'primary': True,
#       'shortName': 'Event Space'}],
#     'hasPerk': False,
#     'id': '4f27e8e1e4b00c38330cccc9',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 7975,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.723286033638736,
#        'lng': -79.41222238138339}],
#      'lat': 43.723286033638736,
#      'lng': -79.41222238138339},
#     'name': 'Cafeteria, Lawrence Park Collegiate',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '52e057c6498e06465c4cf155',
#     'location': {'address': '958 Broadview avenue',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 3874,
#      'formattedAddress': ['958 Broadview avenue', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6817626953125,
#        'lng': -79.35824584960938}],
#      'lat': 43.6817626953125,
#      'lng': -79.35824584960938,
#      'state': 'ON'},
#     'name': 'Estonian House Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ca20c19e44d6dcb7c780375',
#     'location': {'address': '30 Bond St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': "in St. Michael's Hospital",
#      'distance': 674,
#      'formattedAddress': ["30 Bond St. (in St. Michael's Hospital)",
#       'Toronto ON M5B 1W8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65358503163883,
#        'lng': -79.3788427000424}],
#      'lat': 43.65358503163883,
#      'lng': -79.3788427000424,
#      'postalCode': 'M5B 1W8',
#      'state': 'ON'},
#     'name': 'Marketeria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '4b72be43f964a5206f862de3',
#     'location': {'address': '350 Victoria St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Ryerson University',
#      'distance': 738,
#      'formattedAddress': ['350 Victoria St. (at Ryerson University)',
#       'Toronto ON M5B 2K3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65858470645715,
#        'lng': -79.38062166535785}],
#      'lat': 43.65858470645715,
#      'lng': -79.38062166535785,
#      'postalCode': 'M5B 2K3',
#      'state': 'ON'},
#     'name': 'The Hub',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '5154668be4b0b8a533fe49db',
#     'location': {'address': '951 Carlaw Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Mortimer Ave',
#      'distance': 4603,
#      'formattedAddress': ['951 Carlaw Ave (at Mortimer Ave)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.68463134765625,
#        'lng': -79.34886169433594}],
#      'lat': 43.68463134765625,
#      'lng': -79.34886169433594,
#      'state': 'ON'},
#     'name': 'CC Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/communitycollege_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a2941735',
#       'name': 'Community College',
#       'pluralName': 'Community Colleges',
#       'primary': True,
#       'shortName': 'Community College'}],
#     'hasPerk': False,
#     'id': '4b60cb0ef964a520dbf929e3',
#     'location': {'address': '51 Dockside Dr',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'George',
#      'distance': 2001,
#      'formattedAddress': ['51 Dockside Dr (George)',
#       'Toronto ON M5A 0B6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6441628,
#        'lng': -79.3663752}],
#      'lat': 43.6441628,
#      'lng': -79.3663752,
#      'postalCode': 'M5A 0B6',
#      'state': 'ON'},
#     'name': 'George Brown College St. James Campus',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'primary': True,
#       'shortName': 'Food Court'}],
#     'hasPerk': False,
#     'id': '4ebaa7b49a5284afeac64b01',
#     'location': {'address': '333 Bloor st east',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 2044,
#      'formattedAddress': ['333 Bloor st east', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67169582147495,
#        'lng': -79.38061690003971}],
#      'lat': 43.67169582147495,
#      'lng': -79.38061690003971,
#      'state': 'ON'},
#     'name': 'Radio Cafe',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'primary': True,
#       'shortName': 'High School'}],
#     'hasPerk': False,
#     'id': '4f231b64e4b0476578527490',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 7950,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7227573665374,
#        'lng': -79.4137339398847}],
#      'lat': 43.7227573665374,
#      'lng': -79.4137339398847,
#      'state': 'ON'},
#     'name': 'Lawrence Park Collegiate Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cuban_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d154941735',
#       'name': 'Cuban Restaurant',
#       'pluralName': 'Cuban Restaurants',
#       'primary': True,
#       'shortName': 'Cuban'}],
#     'hasPerk': False,
#     'id': '509d56d1e4b083e9a4a2e15d',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 8404,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.723019,
#        'lng': -79.345012}],
#      'lat': 43.723019,
#      'lng': -79.345012},
#     'name': 'L5 Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'primary': True,
#       'shortName': 'Cafeteria'}],
#     'hasPerk': False,
#     'id': '4ceb03e6948f224b2590fe5d',
#     'location': {'address': '2275 Bayview Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Bayview Ave and Lawrence Ave E',
#      'distance': 8206,
#      'formattedAddress': ['2275 Bayview Ave (Bayview Ave and Lawrence Ave E)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72738324244186,
#        'lng': -79.37807978359076}],
#      'lat': 43.72738324244186,
#      'lng': -79.37807978359076,
#      'state': 'ON'},
#     'name': 'Glendon Cafeteria',
#     'referralId': 'v-1560853948'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4e6f9bced4c06eaf9c42b60f',
#     'location': {'address': '435 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at College St.',
#      'distance': 1072,
#      'formattedAddress': ['435 Spadina Ave. (at College St.)',
#       'Toronto ON M5T 2T6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65739935200925,
#        'lng': -79.39964945212796}],
#      'lat': 43.65739935200925,
#      'lng': -79.39964945212796,
#      'postalCode': 'M5T 2T6',
#      'state': 'ON'},
#     'name': 'One Hour',
#     'referralId': 'v-1560853948'}]}}

# %%
# Lets assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Fast Food Restaurant', 'id': '4bf58...    False
# 1  [{'name': 'Asian Restaurant', 'id': '4bf58dd8d...    False
# 2  [{'name': 'Mexican Restaurant', 'id': '4bf58dd...    False
# 3  [{'name': 'College Cafeteria', 'id': '4bf58dd8...    False
# 4  [{'name': 'Cafeteria', 'id': '4bf58dd8d48988d1...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  56b2c90a498e9f0e73d6bed6                             974 College St
# 3  4ec2b68a8231a83de8c45191                             100 McCaul St.
# 4  53bd6dfe498e6c1d3bc9333e                                        NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada                  NaN
# 3          CA       Toronto           Canada         Second Floor
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                372  [The Hospital for Sick Children (SickKids), To...
# 1                977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2               3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 3                389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 4                260                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.65341883567197...     43.653419
# 3  [{'label': 'display', 'lat': 43.65278016892648...     43.652780
# 4  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.427678             M6H 1A5             ON
# 3    -79.391762                 NaN             ON
# 4    -79.389443                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1560853948
# 1              Stay Cafeteria 慢走  v-1560853948
# 2                      Cafeteria  v-1560853948
# 3                 OCAD Cafeteria  v-1560853948
# 4  Industrial Alliance Cafeteria  v-1560853948

# %%
# Lets keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                      Cafeteria    Mexican Restaurant
# 3                 OCAD Cafeteria     College Cafeteria
# 4  Industrial Alliance Cafeteria             Cafeteria
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                             974 College St  CA  Toronto  Canada
# 3                             100 McCaul St.  CA  Toronto  Canada
# 4                                        NaN  CA  Toronto  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       372  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St       977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2           NaN      3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 3  Second Floor       389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 4           NaN       260                               [Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.65341883567197...  43.653419 -79.427678
# 3  [{'label': 'display', 'lat': 43.65278016892648...  43.652780 -79.391762
# 4  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2    M6H 1A5    ON  56b2c90a498e9f0e73d6bed6
# 3        NaN    ON  4ec2b68a8231a83de8c45191
# 4        NaN    ON  53bd6dfe498e6c1d3bc9333e

# %%
# Lets delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                               Cafeteria    Mexican Restaurant
# 3                          OCAD Cafeteria     College Cafeteria
# 4           Industrial Alliance Cafeteria             Cafeteria
# 5                         Dears Cafeteria          Dessert Shop
# 6                 Chestnut Tree Cafeteria             Cafeteria
# 7                         Sears Cafeteria            Food Court
# 8           De La Salle College Cafeteria     College Cafeteria
# 9                       Med Sci Cafeteria     College Cafeteria
# 10                  Ryerson Hub Cafeteria     College Cafeteria
# 11                     SickKids Cafeteria            Food Court
# 12              Macdonald Block Cafeteria             Cafeteria
# 13                       Rogers Cafeteria            Food Court
# 14                      Robarts Cafeteria     College Cafeteria
# 15                          OMP Cafeteria             Cafeteria
# 16                      Choices Cafeteria            Food Court
# 17    Cafeteria, Lawrence Park Collegiate           High School
# 18                       Kasala Cafeteria    African Restaurant
# 19    Cafeteria, Lawrence Park Collegiate           Event Space
# 20               Estonian House Cafeteria                  Café
# 21                             Marketeria            Restaurant
# 22                                The Hub     College Cafeteria
# 23                           CC Cafeteria     College Cafeteria
# 24  George Brown College St. James Campus     Community College
# 25                             Radio Cafe            Food Court
# 26     Lawrence Park Collegiate Cafeteria           High School
# 27                           L5 Cafeteria      Cuban Restaurant
# 28                      Glendon Cafeteria     College Cafeteria
# 29                               One Hour    Chinese Restaurant
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                              974 College St  43.653419 -79.427678
# 3                              100 McCaul St.  43.652780 -79.391762
# 4                                         NaN  43.655657 -79.389443
# 5                                         NaN  43.654179 -79.392555
# 6                          89 Chestnut Street  43.648231 -79.384045
# 7                                       Yonge  43.656038 -79.380672
# 8                          131 Farnham Avenue  43.683003 -79.397815
# 9                                         NaN  43.660260 -79.392977
# 10                           350 Victoria St.  43.658475 -79.377653
# 11                      555 University Avenue  43.657584 -79.375652
# 12                                        NaN  43.663212 -79.388062
# 13                                        NaN  43.669904 -79.379748
# 14                         130 St. George St.  43.664864 -79.399766
# 15                           1 Mount Pleasant  43.669801 -79.379790
# 16                         200 Bloor Street E  43.671411 -79.381849
# 17                                        NaN  43.721732 -79.409600
# 18                                      Bloor  43.660759 -79.424018
# 19                                        NaN  43.723286 -79.412222
# 20                       958 Broadview avenue  43.681763 -79.358246
# 21                                30 Bond St.  43.653585 -79.378843
# 22                           350 Victoria St.  43.658585 -79.380622
# 23                             951 Carlaw Ave  43.684631 -79.348862
# 24                             51 Dockside Dr  43.644163 -79.366375
# 25                          333 Bloor st east  43.671696 -79.380617
# 26                                        NaN  43.722757 -79.413734
# 27                                        NaN  43.723019 -79.345012
# 28                           2275 Bayview Ave  43.727383 -79.378080
# 29                           435 Spadina Ave.  43.657399 -79.399649
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2     M6H 1A5    ON
# 3         NaN    ON
# 4         NaN    ON
# 5         NaN   NaN
# 6         NaN    ON
# 7         NaN    ON
# 8     M4V 1H7    ON
# 9         NaN    ON
# 10        NaN    ON
# 11        NaN    ON
# 12        NaN   NaN
# 13        NaN    ON
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN    ON
# 17        NaN   NaN
# 18        NaN   NaN
# 19        NaN   NaN
# 20        NaN    ON
# 21    M5B 1W8    ON
# 22    M5B 2K3    ON
# 23        NaN    ON
# 24    M5A 0B6    ON
# 25        NaN    ON
# 26        NaN    ON
# 27        NaN   NaN
# 28        NaN    ON
# 29    M5T 2T6    ON

# %%
# Lets delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name          categories  \
# 1                       Stay Cafeteria 慢走    Asian Restaurant
# 2                               Cafeteria  Mexican Restaurant
# 8           De La Salle College Cafeteria   College Cafeteria
# 21                             Marketeria          Restaurant
# 22                                The Hub   College Cafeteria
# 24  George Brown College St. James Campus   Community College
# 29                               One Hour  Chinese Restaurant
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 2       974 College St  43.653419 -79.427678    M6H 1A5    ON
# 8   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 21         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 22    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 24      51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 29    435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON

# %%
# Lets search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=J1F24KJMK4YD0QK00HGFLEOBJRKH5XGLOJBPY4DLKSQGPKK0&client_secret=LAJR2Q0ZUAGDBFPRY4N3AQF50NBK0WSBYZX0RVFMHZWP5JU0&ll=43.653963,-79.387207&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Lets send the GET Request and examine the results
sresults = requests.get(url).json()
sresults
# Out:
# {'meta': {'code': 200, 'requestId': '5d08bdf9c53093002c311b80'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'primary': True,
#       'shortName': 'Mall'}],
#     'hasPerk': False,
#     'id': '4ad4c062f964a520fcf720e3',
#     'location': {'address': '280 Spadina Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Dundas St W',
#      'distance': 897,
#      'formattedAddress': ['280 Spadina Ave (at Dundas St W)',
#       'Toronto ON M5T 3A5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65277367198862,
#        'lng': -79.39822232898479}],
#      'lat': 43.65277367198862,
#      'lng': -79.39822232898479,
#      'postalCode': 'M5T 3A5',
#      'state': 'ON'},
#     'name': 'Dragon City Shopping Mall 龍城',
#     'referralId': 'v-1560854009'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'primary': True,
#       'shortName': 'Mall'}],
#     'hasPerk': False,
#     'id': '4b9e86dff964a520e6eb36e3',
#     'location': {'address': '66 Wellington St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btw York & Bay St',
#      'distance': 908,
#      'formattedAddress': ['66 Wellington St W (btw York & Bay St)',
#       'Toronto ON M5K 1A1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64718424611984,
#        'lng': -79.38093185357147}],
#      'lat': 43.64718424611984,
#      'lng': -79.38093185357147,
#      'postalCode': 'M5K 1A1',
#      'state': 'ON'},
#     'name': 'TD Centre Shopping Concourse',
#     'referralId': 'v-1560854009'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'primary': True,
#       'shortName': 'Mall'}],
#     'hasPerk': False,
#     'id': '4ad77a12f964a520260b21e3',
#     'location': {'address': '220 Yonge St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn Queen & Dundas',
#      'distance': 527,
#      'formattedAddress': ['220 Yonge St (btwn Queen & Dundas)',
#       'Toronto ON M5B 2H1',
#       'Canada'],
#      'lat': 43.65385223516321,
#      'lng': -79.38065538953805,
#      'neighborhood': 'Downtown Toronto, Toronto, ON',
#      'postalCode': 'M5B 2H1',
#      'state': 'ON'},
#     'name': 'CF Toronto Eaton Centre',
#     'referralId': 'v-1560854009'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'primary': True,
#       'shortName': 'Department Store'}],
#     'hasPerk': False,
#     'id': '5840cafe06f1a34af80cc609',
#     'location': {'address': '176 Yonge Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Queen Street West',
#      'distance': 688,
#      'formattedAddress': ['176 Yonge Street (Queen Street West)',
#       'Toronto ON M5C 2L7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65181,
#        'lng': -79.379192}],
#      'lat': 43.65181,
#      'lng': -79.379192,
#      'postalCode': 'M5C 2L7',
#      'state': 'ON'},
#     'name': 'Saks Fifth Avenue Club - Personal Shopping',
#     'referralId': 'v-1560854009'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '4b83d653f964a520d91231e3',
#     'location': {'address': '461 King St. West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 974,
#      'formattedAddress': ['461 King St. West', 'Toronto ON M5V 1K4', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64795765580337,
#        'lng': -79.39600592454082}],
#      'lat': 43.64795765580337,
#      'lng': -79.39600592454082,
#      'postalCode': 'M5V 1K4',
#      'state': 'ON'},
#     'name': 'Yellow Pages - RedFlagDeals.com',
#     'referralId': 'v-1560854009'}]}}

# %%
# Lets assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Shopping Mall', 'id': '4bf58dd8d489...    False
# 1  [{'name': 'Shopping Mall', 'id': '4bf58dd8d489...    False
# 2  [{'name': 'Shopping Mall', 'id': '4bf58dd8d489...    False
# 3  [{'name': 'Department Store', 'id': '4bf58dd8d...    False
# 4  [{'name': 'Office', 'id': '4bf58dd8d48988d1249...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ad4c062f964a520fcf720e3     280 Spadina Ave          CA       Toronto
# 1  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 2  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 3  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 4  4b83d653f964a520d91231e3   461 King St. West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada       at Dundas St W                897
# 1           Canada    btw York & Bay St                908
# 2           Canada  btwn Queen & Dundas                527
# 3           Canada    Queen Street West                688
# 4           Canada                  NaN                974
#
#                            location.formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [66 Wellington St W (btw York & Bay St), Toron...
# 2  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...     43.652774
# 1  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 2                                                NaN     43.653852
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 4  [{'label': 'display', 'lat': 43.64795765580337...     43.647958
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.398222                            NaN             M5T 3A5
# 1    -79.380932                            NaN             M5K 1A1
# 2    -79.380655  Downtown Toronto, Toronto, ON             M5B 2H1
# 3    -79.379192                            NaN             M5C 2L7
# 4    -79.396006                            NaN             M5V 1K4
#
#   location.state                                        name    referralId
# 0             ON                Dragon City Shopping Mall 龍城  v-1560854009
# 1             ON                TD Centre Shopping Concourse  v-1560854009
# 2             ON                     CF Toronto Eaton Centre  v-1560854009
# 3             ON  Saks Fifth Avenue Club - Personal Shopping  v-1560854009
# 4             ON             Yellow Pages - RedFlagDeals.com  v-1560854009

# %%
# Lets keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                TD Centre Shopping Concourse     Shopping Mall
# 2                     CF Toronto Eaton Centre     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address  cc     city country          crossStreet  distance  \
# 0     280 Spadina Ave  CA  Toronto  Canada       at Dundas St W       897
# 1  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       908
# 2        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       527
# 3    176 Yonge Street  CA  Toronto  Canada    Queen Street West       688
# 4   461 King St. West  CA  Toronto  Canada                  NaN       974
#
#                                     formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [66 Wellington St W (btw York & Bay St), Toron...
# 2  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...  43.652774 -79.398222
# 1  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
# 2                                                NaN  43.653852 -79.380655
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 4  [{'label': 'display', 'lat': 43.64795765580337...  43.647958 -79.396006
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5T 3A5    ON  4ad4c062f964a520fcf720e3
# 1                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 2  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 3                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 4                            NaN    M5V 1K4    ON  4b83d653f964a520d91231e3

# %%
# Lets delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                TD Centre Shopping Concourse     Shopping Mall
# 2                     CF Toronto Eaton Centre     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 2        220 Yonge St  43.653852 -79.380655    M5B 2H1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
# Lets delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
# 2       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.653852
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380932    M5K 1A1    ON
# 2 -79.380655    M5B 2H1    ON

# %%
# Generate map
# Lets create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                      name          categories  \
# 0           Sheraton Centre Toronto Hotel               Hotel
# 1                          Grand Ballroom         Event Space
# 2                       Stay Cafeteria 慢走    Asian Restaurant
# 3                               Cafeteria  Mexican Restaurant
# 4           De La Salle College Cafeteria   College Cafeteria
# 5                              Marketeria          Restaurant
# 6                                 The Hub   College Cafeteria
# 7   George Brown College St. James Campus   Community College
# 8                                One Hour  Chinese Restaurant
# 9            Dragon City Shopping Mall 龍城       Shopping Mall
# 10           TD Centre Shopping Concourse       Shopping Mall
# 11                CF Toronto Eaton Centre       Shopping Mall
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 1         123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 2         388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3          974 College St  43.653419 -79.427678    M6H 1A5    ON
# 4      131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 5             30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 6        350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 7          51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 8        435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 9         280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 10     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 11           220 Yonge St  43.653852 -79.380655    M5B 2H1    ON

# %%
# Lets generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Lets create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name               categories  \
# 0                           Trinity Bellwoods Park                     Park
# 1                             Bellevue Square Park                     Park
# 2                                     Queen's Park                     Park
# 3                                        High Park                     Park
# 4                              Riverdale Park West                     Park
# 5                              Riverdale Park East                     Park
# 6                                  Coronation Park                     Park
# 7                               Canoe Landing Park                     Park
# 8                                Barbara Hall Park                     Park
# 9                  Hemispheres Restaurant & Bistro      American Restaurant
# 10                          Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 11                          Azure Restaurant & Bar               Restaurant
# 12                           Victoria's Restaurant               Restaurant
# 13                                  360 Restaurant                 Wine Bar
# 14                  Goldstone Noodle Restaurant 金石             Noodle House
# 15                         Victor Restaurant & Bar                      Bar
# 16                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 17                   Green Tea Restaurant Downtown       Chinese Restaurant
# 18                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 19                  The Hot House Restaurant & Bar      American Restaurant
# 20         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 21                        Ka Chi Korean Restaurant        Korean Restaurant
# 22                    Aroma Fine Indian Restaurant        Indian Restaurant
# 23                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 24  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 25                      Matisse Restaurant And Bar               Restaurant
# 26                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 27                  Insomnia Restaurant and Lounge               Restaurant
# 28                         The Lakeview Restaurant                    Diner
# 29                               Tundra Restaurant               Restaurant
# 30                     Woodlot Restaurant & Bakery  New American Restaurant
# 31                               Studio Restaurant           Breakfast Spot
# 32                            Montecito Restaurant               Restaurant
# 33               Kensington Cornerstone Restaurant           Breakfast Spot
# 34                     Cottage Restaurant & Lounge          Thai Restaurant
# 35                               Stay Cafeteria 慢走         Asian Restaurant
# 36                                       Cafeteria       Mexican Restaurant
# 37                   De La Salle College Cafeteria        College Cafeteria
# 38                                      Marketeria               Restaurant
# 39                                         The Hub        College Cafeteria
# 40           George Brown College St. James Campus        Community College
# 41                                        One Hour       Chinese Restaurant
#
#                             address        lat        lng postalCode state
# 0                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 1      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 2                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 3                  1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 4                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 5                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 6            711 Lake Shore Blvd. W  43.634553 -79.405403    M5V 3T7    ON
# 7                 50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 8                     519 Church St  43.666879 -79.381068    M4Y 2K9    ON
# 9               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 10                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 11                    225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 12              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 13                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 14                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 15                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 16                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 17  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 18                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 19                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 20                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 21                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 22                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 23                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 24            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 25                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 26           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 27                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 28                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 29         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 30              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 31                   389 Church St.  43.661500 -79.379319        M5B    ON
# 32                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 33               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 34                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 35                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 36                   974 College St  43.653419 -79.427678    M6H 1A5    ON
# 37               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 38                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 39                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 40                   51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 41                 435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON

# %%
# Lets generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
